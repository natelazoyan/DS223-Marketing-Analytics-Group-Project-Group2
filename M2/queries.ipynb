# %%
from etl.data_preparation import SqlHandler
import pandas as pd

# %%
Inst = SqlHandler('temp', ['sales_fact','transactions','customer','property','agent','date'])

# %%
# Retrieve properties with square footage greater than 1500.
query1 = "SELECT * FROM property WHERE square_footage > 1500;"

# Retrieve customers from New York born after January 1, 1990.
query2 = "SELECT * FROM customer WHERE birthday > '1990-01-01' AND city = 'New York';"

# Retrieve agents with more than 5 years of experience.
query3 = "SELECT * FROM agent WHERE experience_years > 5;"

# Retrieve transactions made using credit cards.
query4 = "SELECT * FROM transactions WHERE payment_method = 'Credit Card';"

# Retrieve sales transactions where the transaction amount is over 100000.
query5 = "SELECT * FROM sales_fact WHERE transaction_id IN (SELECT transaction_id FROM transactions WHERE transaction_amount > 100000);"

# Retrieve property sales made in the year 2022.
query6 = "SELECT * FROM property p JOIN sales_fact s ON p.property_id = s.property_id JOIN date d ON s.date_id = d.date_id WHERE d.year = 2022;"

# Retrieve sales transactions handled by agent with ID 5.
query7 = "SELECT * FROM sales_fact WHERE agent_id = 5;"

# Calculate total transaction amounts grouped by month and year for the year 2023.
query8 = "SELECT d.month, d.year, SUM(t.transaction_amount) AS total_amount FROM transactions t JOIN date d ON strftime('%Y', t.transaction_date) = d.year WHERE d.year = 2023 GROUP BY d.month, d.year;"

# Count the number of properties in each city.
query9 = "SELECT city, COUNT(*) AS property_count FROM property GROUP BY city;"

# Calculate the average number of bathrooms for properties built after 2010.
query10 = "SELECT AVG(number_of_bathrooms) AS avg_bathrooms FROM property WHERE year_built > 2010;"

# Calculate total transaction amounts grouped by property type in a specific city.
query11 = "SELECT p.property_type, SUM(t.transaction_amount) AS total_transaction_amount FROM property p LEFT JOIN sales_fact s ON p.property_id = s.property_id LEFT JOIN transactions t ON s.transaction_id = t.transaction_id WHERE p.city = 'East Samuel' GROUP BY p.property_type;"

# Calculate the average square footage of properties sold by agents with more than 5 years of experience.
query12 = "SELECT AVG(p.square_footage) AS average_square_footage FROM property p JOIN sales_fact s ON p.property_id = s.property_id JOIN agent a ON s.agent_id = a.agent_id WHERE a.experience_years > 5;"

# Retrieve top 5 customers with the highest total transaction amounts.
query13 = "SELECT c.customer_name, c.customer_surname, SUM(t.transaction_amount) AS total_transactions FROM customer c JOIN sales_fact s ON c.customer_id = s.customer_id JOIN transactions t ON s.transaction_id = t.transaction_id GROUP BY c.customer_id ORDER BY total_transactions DESC LIMIT 5;"

# Retrieve properties that were not involved in any sales transactions.
query14 = "SELECT p.* FROM property p LEFT JOIN sales_fact s ON p.property_id = s.property_id WHERE s.property_id IS NULL;"

# Retrieve the agent with the highest number of transactions in Spain.
query15 = "SELECT a.agent_name, a.agent_surname, COUNT(s.transaction_id) AS transaction_count FROM agent a JOIN sales_fact s ON a.agent_id = s.agent_id JOIN customer c ON s.customer_id = c.customer_id WHERE c.country = 'Spain' GROUP BY a.agent_id ORDER BY transaction_count DESC LIMIT 1;"

# Calculate total transaction amounts grouped by quarter for the year 2010.
query16 = "SELECT d.quarter, SUM(t.transaction_amount) AS total_sales_amount FROM transactions t JOIN date d ON strftime('%Y', t.transaction_date) = d.year WHERE d.year = 2010 GROUP BY d.quarter;"

# Retrieve customer details for customers who bought properties in the same city they were born in and in the year their birth year matches the property's year built.
query17 = "SELECT c.* FROM customer c JOIN sales_fact s ON c.customer_id = s.customer_id JOIN property p ON s.property_id = p.property_id WHERE c.city = p.city AND strftime('%Y', c.birthday) = strftime('%Y', p.year_built);"

# Retrieve properties where the number of bedrooms equals the number of bathrooms.
query18 = "SELECT * FROM property WHERE number_of_bedrooms = number_of_bathrooms;"

# Calculate the average customer age at the time of their transactions.
query19 = "SELECT AVG(strftime('%Y', 'now') - strftime('%Y', c.birthday)) AS average_customer_age FROM customer c JOIN sales_fact s ON c.customer_id = s.customer_id;"

# Calculate the total number of transactions grouped by day of the week, and retrieve the busiest day.
query20 = "SELECT d.day_of_week_name, COUNT(s.transaction_id) AS transaction_count FROM sales_fact s JOIN date d ON s.date_id = d.date_id GROUP BY d.day_of_week_name ORDER BY transaction_count DESC LIMIT 1;"


queries = [query1,
query2,
query3,
query4,
query5 ,
query6,
query7,
query8,
query9,
query10,
query11,
query12,
query13,
query14,
query15,
query16,
query17,
query18,
query19,
query20]

# %%
ls = []
for i in queries:
    ls.append(Inst.execute_custom_query(i))

# %%
count = 0
for i in ls:
    count+=1
    print(f'query {count}')
    print(pd.DataFrame(i))
    print("_______________")
# Out:
# query 1
#          0          1              2               3                  4  \
# 0        0       Loft       Mongolia     East Samuel  Christopher Trace
# 1        1     Duplex        Uruguay    South Jasmin          Hall Camp
# 2        2     Duplex     Bangladesh    North Adrian     Davis Crossing
# 3        3      Condo         Taiwan  Jeffreychester        Perry Hills
# 4        5      House        Namibia         Sototon         Ian Corner
# ...    ...        ...            ...             ...                ...
# 4668  4994  Apartment       Cambodia        Chenland     Alyssa Estates
# 4669  4995    Cottage        Belarus       Meganview    Barton Mountain
# 4670  4996    Cottage        Nigeria       Conleyton      Robinson Oval
# 4671  4997    Cottage   Saint Martin     North James       Donna Ridges
# 4672  4999       Loft  Cote d'Ivoire     Port Sheila       David Island
#
#           5      6   7   8     9
# 0       293  13092   6   5  2022
# 1      5545  10223   4  10  2017
# 2      5238  10470   3   5  2016
# 3     98187  18383   5  10  2009
# 4      5547  18232   2   7  2003
# ...     ...    ...  ..  ..   ...
# 4668    678   9402   7   7  2022
# 4669  11250   7791   1   4  2003
# 4670  24033  16662   9   6  2002
# 4671   6452   6380   5   5  2001
# 4672    721   3029  10   2  2010
#
# [4673 rows x 10 columns]
# _______________
# query 2
# Empty DataFrame
# Columns: []
# Index: []
# _______________
# query 3
#          0        1          2                              3  \
# 0        1      Pam    Donovan       gravesmorgan@example.org
# 1        2  Michael       Hill           kimemily@example.org
# 2        3     Paul   Castillo  jeremyblankenship@example.com
# 3        5     John      Moore        joelmorales@example.org
# 4        6   Hannah      Meyer              ikoch@example.net
# ...    ...      ...        ...                            ...
# 1838  1993  Colleen     Wilson    rodriguezthomas@example.org
# 1839  1994     John    Coleman         sarahmyers@example.net
# 1840  1995   Amanda  Hernandez            peter05@example.com
# 1841  1998    Kelly      Lewis            ymiller@example.com
# 1842  1999   Gloria   Carrillo  williamschristina@example.org
#
#                           4   5
# 0       +1-988-817-4914x437  41
# 1          001-666-617-0076  26
# 2      001-813-770-9290x795  65
# 3           +1-445-480-0392  40
# 4          649-618-0977x254  69
# ...                     ...  ..
# 1838           426-578-2552  34
# 1839           578.962.3322  28
# 1840           899.889.6924  78
# 1841          (570)357-5400  36
# 1842  001-944-352-2902x5334  62
#
# [1843 rows x 6 columns]
# _______________
# query 4
#         0           1                    2            3
# 0       3  1576236.27  2009-10-16 04:30:05  Credit Card
# 1       4   191146.66  2020-06-11 01:24:48  Credit Card
# 2       7   225740.70  2002-07-03 13:15:00  Credit Card
# 3       8  1619606.53  2004-08-06 10:37:56  Credit Card
# 4      12   836082.75  2022-11-08 15:16:16  Credit Card
# ..    ...         ...                  ...          ...
# 674  3974   408397.52  2006-09-17 09:58:04  Credit Card
# 675  3976   722463.66  2013-05-20 10:04:44  Credit Card
# 676  3981   581787.15  2001-07-13 06:19:40  Credit Card
# 677  3985   843230.63  2000-08-31 22:11:35  Credit Card
# 678  3989  1758875.26  2009-04-09 06:13:44  Credit Card
#
# [679 rows x 4 columns]
# _______________
# query 5
#          0     1     2     3     4     5
# 0        1     1  4324  1542   166  4219
# 1        2     2  2955  2779   308  8145
# 2        3     3   339  2637  1838  4176
# 3        4     4  4906   103   609  4740
# 4        5     5  3478   202    28  2518
# ...    ...   ...   ...   ...   ...   ...
# 3948  3995  3995  2862  2271   148  7243
# 3949  3996  3996  2503   788  1439  3804
# 3950  3997  3997   796  2474   533  4809
# 3951  3998  3998  1474   286   384  6626
# 3952  3999  3999  4032  1349   574  5137
#
# [3953 rows x 6 columns]
# _______________
# query 6
#        0          1                         2               3   \
# 0    2955     Studio          Pitcairn Islands  Christinashire
# 1      24  Penthouse               Isle of Man       Aprilside
# 2    4712      House                      Iran        Duaneton
# 3    4405  Apartment                  Zimbabwe  West Stephanie
# 4    3623     Duplex  United States of America   East Tinaview
# ..    ...        ...                       ...             ...
# 151  3196     Studio                    Greece     Cassidyberg
# 152  3509      House                Montenegro   Gonzalezville
# 153  1849  Penthouse               Saint Lucia     Lake Dalton
# 154  3251       Loft                    Monaco       Scottberg
# 155  3062     Duplex                Kazakhstan   West Ericbury
#
#                       4      5      6   7   8     9   ...  18         19  \
# 0         Anthony Tunnel   1599   8759   4   8  2001  ...   4      April
# 1           Daniel Ridge   2405  12614   7  10  2014  ...  10    October
# 2       Cervantes Groves  13755  17381  10   1  2005  ...   1    January
# 3           Bobby Cliffs  65040    866   5   1  2020  ...   9  September
# 4          Debra Heights   7365   3983   1   6  2017  ...   4      April
# ..                   ...    ...    ...  ..  ..   ...  ...  ..        ...
# 151        Chavez Tunnel    938   3319   2   3  2009  ...   2   February
# 152      Timothy Islands  33011  18185   2   2  2007  ...   1    January
# 153  Stephanie Underpass  73196  12393   8   3  2008  ...  12   December
# 154          David Parks  43369  19177   1   1  2002  ...   8     August
# 155          Hart Island  42862   5489   4   7  2015  ...   1    January
#
#        20  21  22   23  24         25  26 27
# 0    2022   2  20  110   3  Wednesday  16  3
# 1    2022   4  14  287   5     Friday  41  2
# 2    2022   1  17   17   1     Monday   3  3
# 3    2022   3  11  254   7     Sunday  36  2
# 4    2022   2  15  105   5     Friday  15  3
# ..    ...  ..  ..  ...  ..        ...  .. ..
# 151  2022   1  21   52   1     Monday   8  3
# 152  2022   1   1    1   6   Saturday  52  1
# 153  2022   4  12  346   1     Monday  50  2
# 154  2022   3  27  239   6   Saturday  34  4
# 155  2022   1  26   26   3  Wednesday   4  4
#
# [156 rows x 28 columns]
# _______________
# query 7
#       0     1     2     3  4     5
# 0  2270  2270  1779  1146  5  2769
# 1  3562  3562    37  1968  5  8399
# _______________
# query 8
#      0     1             2
# 0    1  2023  6.147404e+09
# 1    2  2023  5.552494e+09
# 2    3  2023  6.147404e+09
# 3    4  2023  5.949100e+09
# 4    5  2023  6.147404e+09
# 5    6  2023  5.949100e+09
# 6    7  2023  6.147404e+09
# 7    8  2023  6.147404e+09
# 8    9  2023  5.949100e+09
# 9   10  2023  6.147404e+09
# 10  11  2023  5.949100e+09
# 11  12  2023  6.147404e+09
# _______________
# query 9
#                    0  1
# 0       Aaronchester  1
# 1          Aaronfort  1
# 2          Aaronfurt  1
# 3          Aaronland  1
# 4         Aaronmouth  1
# ...              ... ..
# 4298    Zacharyville  1
# 4299   Zamoraborough  1
# 4300      Zavalastad  1
# 4301  Zimmermanhaven  1
# 4302     Zunigaburgh  1
#
# [4303 rows x 2 columns]
# _______________
# query 10
#           0
# 0  5.469191
# _______________
# query 11
#       0     1
# 0  Loft  None
# _______________
# query 12
#               0
# 0  10024.310542
# _______________
# query 13
#           0          1           2
# 0       Amy      Smith  7754714.26
# 1      Jodi    Summers  7151017.20
# 2    Amanda       Berg  6925938.68
# 3      Anna  Jefferson  6725621.13
# 4  Kimberly       Cook  6721265.44
# _______________
# query 14
#          0          1                 2                3                  4  \
# 0        0       Loft          Mongolia      East Samuel  Christopher Trace
# 1        3      Condo            Taiwan   Jeffreychester        Perry Hills
# 2        5      House           Namibia          Sototon         Ian Corner
# 3        7  Penthouse           Jamaica   Griffinborough          Eric Fork
# 4       11      House           Grenada  New Amandahaven     William Square
# ...    ...        ...               ...              ...                ...
# 2284  4992    Cottage          Maldives     Kathleenland        Steven Camp
# 2285  4993  Penthouse  Saint Barthelemy    Port Kimberly       Reeves Curve
# 2286  4994  Apartment          Cambodia         Chenland     Alyssa Estates
# 2287  4996    Cottage           Nigeria        Conleyton      Robinson Oval
# 2288  4997    Cottage      Saint Martin      North James       Donna Ridges
#
#           5      6   7   8     9
# 0       293  13092   6   5  2022
# 1     98187  18383   5  10  2009
# 2      5547  18232   2   7  2003
# 3      7737  14527  10   8  2002
# 4       425   5255   8   4  2020
# ...     ...    ...  ..  ..   ...
# 2284  51213  13469   1   2  2010
# 2285   6726  17806   5   1  2019
# 2286    678   9402   7   7  2022
# 2287  24033  16662   9   6  2002
# 2288   6452   6380   5   5  2001
#
# [2289 rows x 10 columns]
# _______________
# query 15
#        0       1  2
# 0  Bruce  Flores  1
# _______________
# query 16
#    0             1
# 0  1  1.709423e+10
# 1  2  1.728416e+10
# 2  3  1.747410e+10
# 3  4  1.747410e+10
# _______________
# query 17
# Empty DataFrame
# Columns: []
# Index: []
# _______________
# query 18
#         0          1             2                    3                 4  \
# 0      47     Duplex       Jamaica          Williamston    Edwards Tunnel
# 1      51       Loft   Isle of Man           Fullerland       Thomas Glen
# 2      64  Penthouse         Chile     New Sabrinashire   Roberts Estates
# 3      71  Penthouse    Martinique             Adamfort      Valerie Fork
# 4      80     Duplex         China            West Leah  Bradshaw Centers
# ..    ...        ...           ...                  ...               ...
# 508  4966       Loft        Mexico   New Allisonchester      Madden Vista
# 509  4969      Condo        Canada          Harrisville     Gonzalez Burg
# 510  4977  Penthouse    Azerbaijan  North Nicholasville       Fred Greens
# 511  4994  Apartment      Cambodia             Chenland    Alyssa Estates
# 512  4997    Cottage  Saint Martin          North James      Donna Ridges
#
#          5      6  7  8     9
# 0     3376   5551  2  2  2023
# 1    64122  17955  4  4  2019
# 2       22   3908  8  8  2016
# 3     4056  12532  6  6  2011
# 4     8117  15034  6  6  2019
# ..     ...    ... .. ..   ...
# 508  36236  11431  5  5  2011
# 509    472  11039  9  9  2017
# 510  77032  18369  8  8  2012
# 511    678   9402  7  7  2022
# 512   6452   6380  5  5  2001
#
# [513 rows x 10 columns]
# _______________
# query 19
#            0
# 0  59.635659
# _______________
# query 20
#         0    1
# 0  Sunday  600
# _______________
